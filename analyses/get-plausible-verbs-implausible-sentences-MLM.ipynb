# %%
import os
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# # load stimuli

# %%
data_dir = "/Users/carinakauf/Desktop/ComputationalPlausibility/0_EventsComputational_Dropbox/model_data/EventsRev"

# %%
# # custom function to read a datatable

def read_data(directory,filename):
    df = pd.read_csv(os.path.join(directory,filename), sep='\t', header=None)
    if len(df.columns) == 4:
        df.columns = ['SentenceNum', 'Sentence', 'Plausibility', 'Score']
        df['ItemNum'] = df['SentenceNum']//2 #integer division 5//2 = 2
    elif len(df.columns) == 3:
        df.columns = ['SentenceNum', 'Sentence', 'Score']
        df['ItemNum'] = df['SentenceNum']//2 #integer division 5//2 = 2
        df['Plausibility'] = ['Plausible' if list(df['SentenceNum'])[ind]%2 == 0 else 'Implausible' for ind in range(len(df))]
    else:
        print('unexpected number of columns in file')
    
    df['Metric'] = np.array([filename.split('.txt')[0]]*len(df)).flatten()
    
    return df

# %%
#open sample file
df = read_data(data_dir, 'ANN_xlnet-base-cased.verb.txt')

#get all the implausible sentences
implausible_df = df.loc[df['SentenceNum']%2 == 1]
implausible_df.head()
# Out:
#    SentenceNum                                           Sentence     Score  \
# 1            1                 The criminal is arresting the cop.  0.000550
# 3            3              The child is scolding the babysitter.  0.004207
# 5            5  The patient is using a stethoscope on the doctor.  0.015135
# 7            7           The grandmother is rescuing the fireman.  0.000551
# 9            9               The patient is treating the dentist.  0.000372
#
#    ItemNum Plausibility                     Metric
# 1        0  Implausible  ANN_xlnet-base-cased.verb
# 3        1  Implausible  ANN_xlnet-base-cased.verb
# 5        2  Implausible  ANN_xlnet-base-cased.verb
# 7        3  Implausible  ANN_xlnet-base-cased.verb
# 9        4  Implausible  ANN_xlnet-base-cased.verb

# %%
#get sentences
sentences = list(implausible_df['Sentence'])
sentences[:10]
# Out:
# ['The criminal is arresting the cop.',
#  'The child is scolding the babysitter.',
#  'The patient is using a stethoscope on the doctor.',
#  'The grandmother is rescuing the fireman.',
#  'The patient is treating the dentist.',
#  'The girl is frightening the ghost.',
#  'The baby is feeding the mother.',
#  'The businessman is painting the artist.',
#  'The bride is carrying the groom.',
#  'The king is entertaining the jester.']

# %%
#https://huggingface.co/transformers/main_classes/pipelines.html
#https://huggingface.co/transformers/usage.html
from transformers import pipeline
nlp = pipeline("fill-mask")
nlp_10 = pipeline('fill-mask', top_k=10)
# Out:
# Some weights of RobertaForMaskedLM were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['lm_head.decoder.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of RobertaForMaskedLM were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['lm_head.decoder.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import AutoModelWithLMHead, AutoTokenizer
import torch

tokenizer = AutoTokenizer.from_pretrained("distilbert-base-cased")
model = AutoModelWithLMHead.from_pretrained("distilbert-base-cased")
# Out:
# /Users/carinakauf/repos/transformers/src/transformers/models/auto/modeling_auto.py:915: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(

# %% [markdown]
# #### What pipeline("fill-mask") does
#
# * Instantiate a tokenizer and a model from the checkpoint name. The model is identified as a DistilBERT model and loads it with the weights stored in the checkpoint.
# * Define a sequence with a masked token, placing the tokenizer.mask_token instead of a word.
# * Encode that sequence into IDs and find the position of the masked token in that list of IDs.
# * Retrieve the predictions at the index of the mask token: this tensor has the same size as the vocabulary, and the values are the scores attributed to each token. The model gives higher score to tokens he deems probable in that context.
# * Retrieve the top 5 tokens using the PyTorch topk or TensorFlow top_k methods.
# * Replace the mask token by the tokens and print the results

# %%
#helper function
def effify(non_f_str: str):
    return eval(f'f"""{non_f_str}"""')

# %%
def mask_and_get_predictions(sentence):
    words = sentence.split()
    #print(words)    ['The', 'child', 'is', 'scolding', 'the', 'babysitter.']
    words.insert(3, '{nlp.tokenizer.mask_token}')
    words.pop(4) #needed as this function is applied when one token has already been generated!
    #print(words)    ['The', 'child', 'is', '{nlp.tokenizer.mask_token}', 'the', 'babysitter.']
    
    new_sent = ' '.join(words)
    masked_sent = effify(new_sent)

    predictions_dict = nlp_10(masked_sent)

    return masked_sent, predictions_dict
masked_sent, predictions_dict = mask_and_get_predictions(sentences[1])
predictions_dict
# Out:
# [{'sequence': '<s>The child is not the babysitter.</s>',
#   'score': 0.15501445531845093,
#   'token': 45,
#   'token_str': 'Ġnot'},
#  {'sequence': '<s>The child is now the babysitter.</s>',
#   'score': 0.1106615662574768,
#   'token': 122,
#   'token_str': 'Ġnow'},
#  {'sequence': '<s>The child is suing the babysitter.</s>',
#   'score': 0.10015608370304108,
#   'token': 15449,
#   'token_str': 'Ġsuing'},
#  {'sequence': '<s>The child is also the babysitter.</s>',
#   'score': 0.06446132808923721,
#   'token': 67,
#   'token_str': 'Ġalso'},
#  {'sequence': '<s>The child is assisting the babysitter.</s>',
#   'score': 0.04004541411995888,
#   'token': 13390,
#   'token_str': 'Ġassisting'},
#  {'sequence': '<s>The child is still the babysitter.</s>',
#   'score': 0.03838959336280823,
#   'token': 202,
#   'token_str': 'Ġstill'},
#  {'sequence': '<s>The child is helping the babysitter.</s>',
#   'score': 0.019678765907883644,
#   'token': 1903,
#   'token_str': 'Ġhelping'},
#  {'sequence': '<s>The child is actually the babysitter.</s>',
#   'score': 0.016200823709368706,
#   'token': 888,
#   'token_str': 'Ġactually'},
#  {'sequence': '<s>The child is blaming the babysitter.</s>',
#   'score': 0.01563243567943573,
#   'token': 15249,
#   'token_str': 'Ġblaming'},
#  {'sequence': '<s>The child is being the babysitter.</s>',
#   'score': 0.014720873907208443,
#   'token': 145,
#   'token_str': 'Ġbeing'}]

# %%
def dictionary_to_predictions_csv(implausible_df):
    
    sentences = list(implausible_df["Sentence"])
    sentence_nrs = list(implausible_df["SentenceNum"])
    
    sentence_num, masked = [], []
    sequences, scores, token_ids, tokens = [], [], [], [] #from predictions dictionary

    for ind, elm in enumerate(sentences):
        masked_sent, predictions_dict = mask_and_get_predictions(elm)
        N = len(predictions_dict)

        sentence_num += [sentence_nrs[ind]]*N
        masked += [masked_sent]*N
        sequences += [predictions_dict[ind]["sequence"].lstrip("<s>").rstrip("</s>") for ind in range(N)]
        scores += [predictions_dict[ind]["score"] for ind in range(N)]
        token_ids += [predictions_dict[ind]["token"] for ind in range(N)]
        tokens += [predictions_dict[ind]["token_str"].lstrip("Ġ") for ind in range(N)]
    
    predictions_df = pd.DataFrame({
        "SentenceNum" : sentence_num,
        "InputSent" : masked,
        "PredictedSeq" : sequences,
        "PredictedToken" : tokens,
        "PredictedTokenId" : token_ids,
        "Score" : scores
    })
    
    return predictions_df

# %%
predictions_df = dictionary_to_predictions_csv(implausible_df)

# %%
predictions_df
# Out:
#      SentenceNum                                       InputSent  \
# 0              1                 The criminal is <mask> the cop.
# 1              1                 The criminal is <mask> the cop.
# 2              1                 The criminal is <mask> the cop.
# 3              1                 The criminal is <mask> the cop.
# 4              1                 The criminal is <mask> the cop.
# ..           ...                                             ...
# 395           79  The lady is <mask> the door for the chauffeur.
# 396           79  The lady is <mask> the door for the chauffeur.
# 397           79  The lady is <mask> the door for the chauffeur.
# 398           79  The lady is <mask> the door for the chauffeur.
# 399           79  The lady is <mask> the door for the chauffeur.
#
#                                          PredictedSeq PredictedToken  \
# 0                        The criminal is not the cop.            not
# 1                    The criminal is blaming the cop.        blaming
# 2                      The criminal is suing the cop.          suing
# 3                    The criminal is killing the cop.        killing
# 4                        The criminal is now the cop.            now
# ..                                                ...            ...
# 395  The lady is shutting the door for the chauffeur.       shutting
# 396   The lady is holding the door for the chauffeur.        holding
# 397  The lady is guarding the door for the chauffeur.       guarding
# 398  The lady is blocking the door for the chauffeur.       blocking
# 399  The lady is slamming the door for the chauffeur.       slamming
#
#      PredictedTokenId     Score
# 0                  45  0.107986
# 1               15249  0.056027
# 2               15449  0.055860
# 3                2429  0.042419
# 4                 122  0.029222
# ..                ...       ...
# 395             16099  0.025870
# 396              1826  0.022452
# 397             29454  0.021209
# 398              8890  0.018352
# 399             26963  0.014746
#
# [400 rows x 6 columns]

# %% [markdown]
# # filter out predicted verbs

# %%
#!pip3 install spacy
import spacy.cli
spacy.cli.download("en_core_web_sm")
nlp = spacy.load('en_core_web_sm')

def find_verbs(predictions_df):
    isverb = []
    predicted_sents = list(predictions_df["PredictedSeq"])
    
    for sent in predicted_sents:
        tokens = nlp(sent)
        verb_tok = tokens[3]
        
        if verb_tok.pos_ == "VERB":
            isverb.append(1)
        else:
            isverb.append(0)
    predictions_df["IsVerb"] = isverb
    
    predictions_df.to_csv("bert_MLM_implausibleSentences_EventsRev.csv", index=False)

    return predictions_df
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
out_df = find_verbs(predictions_df)

# %%
out_df
# Out:
#      SentenceNum                                       InputSent  \
# 0              1                 The criminal is <mask> the cop.
# 1              1                 The criminal is <mask> the cop.
# 2              1                 The criminal is <mask> the cop.
# 3              1                 The criminal is <mask> the cop.
# 4              1                 The criminal is <mask> the cop.
# ..           ...                                             ...
# 395           79  The lady is <mask> the door for the chauffeur.
# 396           79  The lady is <mask> the door for the chauffeur.
# 397           79  The lady is <mask> the door for the chauffeur.
# 398           79  The lady is <mask> the door for the chauffeur.
# 399           79  The lady is <mask> the door for the chauffeur.
#
#                                          PredictedSeq PredictedToken  \
# 0                        The criminal is not the cop.            not
# 1                    The criminal is blaming the cop.        blaming
# 2                      The criminal is suing the cop.          suing
# 3                    The criminal is killing the cop.        killing
# 4                        The criminal is now the cop.            now
# ..                                                ...            ...
# 395  The lady is shutting the door for the chauffeur.       shutting
# 396   The lady is holding the door for the chauffeur.        holding
# 397  The lady is guarding the door for the chauffeur.       guarding
# 398  The lady is blocking the door for the chauffeur.       blocking
# 399  The lady is slamming the door for the chauffeur.       slamming
#
#      PredictedTokenId     Score  IsVerb
# 0                  45  0.107986       0
# 1               15249  0.056027       1
# 2               15449  0.055860       1
# 3                2429  0.042419       1
# 4                 122  0.029222       0
# ..                ...       ...     ...
# 395             16099  0.025870       1
# 396              1826  0.022452       1
# 397             29454  0.021209       1
# 398              8890  0.018352       1
# 399             26963  0.014746       1
#
# [400 rows x 7 columns]

# %%
def get_verb_df(out_df, only_best=False):
    verb_frames = []
    for elm in list(np.unique(out_df["SentenceNum"])):
        curr_df = out_df.loc[out_df["SentenceNum"] == elm]
        cnt = 0
        for ind, row in curr_df.iterrows():
            if row["IsVerb"] == 1:
                verb_frames.append(row.to_frame())
                cnt += 1
                if only_best == True:
                    break
        if cnt == 0:
            print(f"no verb predicted for sentence number {elm}")
    verb_df = pd.concat(verb_frames, axis=1)
    verb_df = verb_df.T #swap axes
    
    if only_best == True:
        fout = "bert_MLM_implausibleSentences_EventsRev_bestVerbs.csv"
    else:
        fout = "bert_MLM_implausibleSentences_EventsRev_allVerbs.csv"
    verb_df.to_csv(fout, index=False)
    
    return verb_df
verb_df = get_verb_df(out_df)
verb_df
# Out:
#     SentenceNum                                       InputSent  \
# 1             1                 The criminal is <mask> the cop.
# 2             1                 The criminal is <mask> the cop.
# 3             1                 The criminal is <mask> the cop.
# 12            3             The child is <mask> the babysitter.
# 14            3             The child is <mask> the babysitter.
# ..          ...                                             ...
# 395          79  The lady is <mask> the door for the chauffeur.
# 396          79  The lady is <mask> the door for the chauffeur.
# 397          79  The lady is <mask> the door for the chauffeur.
# 398          79  The lady is <mask> the door for the chauffeur.
# 399          79  The lady is <mask> the door for the chauffeur.
#
#                                          PredictedSeq PredictedToken  \
# 1                    The criminal is blaming the cop.        blaming
# 2                      The criminal is suing the cop.          suing
# 3                    The criminal is killing the cop.        killing
# 12                 The child is suing the babysitter.          suing
# 14             The child is assisting the babysitter.      assisting
# ..                                                ...            ...
# 395  The lady is shutting the door for the chauffeur.       shutting
# 396   The lady is holding the door for the chauffeur.        holding
# 397  The lady is guarding the door for the chauffeur.       guarding
# 398  The lady is blocking the door for the chauffeur.       blocking
# 399  The lady is slamming the door for the chauffeur.       slamming
#
#     PredictedTokenId      Score IsVerb
# 1              15249  0.0560274      1
# 2              15449  0.0558603      1
# 3               2429   0.042419      1
# 12             15449   0.100156      1
# 14             13390  0.0400454      1
# ..               ...        ...    ...
# 395            16099  0.0258698      1
# 396             1826  0.0224516      1
# 397            29454  0.0212087      1
# 398             8890  0.0183519      1
# 399            26963  0.0147458      1
#
# [266 rows x 7 columns]

# %%
best_verb_df = get_verb_df(out_df, only_best=True)
best_verb_df
# Out:
#     SentenceNum                                          InputSent  \
# 1             1                    The criminal is <mask> the cop.
# 12            3                The child is <mask> the babysitter.
# 20            5  The patient is <mask> a stethoscope on the doc...
# 30            7             The grandmother is <mask> the fireman.
# 40            9                 The patient is <mask> the dentist.
# 50           11                      The girl is <mask> the ghost.
# 65           13                     The baby is <mask> the mother.
# 70           15              The businessman is <mask> the artist.
# 87           17                     The bride is <mask> the groom.
# 95           19                     The king is <mask> the jester.
# 100          21      The Safari guide <mask> pouncing on the lion.
# 110          23  The model is <mask> a picture of the photograp...
# 125          25                 The princess is <mask> the pirate.
# 130          27                    The bride is <mask> the priest.
# 140          29                 The snorkeler is <mask> the shark.
# 150          31            The student is <mask> to the professor.
# 161          33                   The woman is <mask> the vampire.
# 171          35                 The customer is <mask> the waiter.
# 180          37          The beggar is <mask> money to the lawyer.
# 190          39                   The lady is <mask> for the chef.
# 200          41           The grandpa is <mask> for the ballerina.
# 211          43           The sportsstar is <mask> the journalist.
# 220          45                  The criminal is <mask> the judge.
# 230          47        The child is <mask> the father on the sled.
# 240          49                The girl is <mask> Santa a present.
# 252          51                The queen is <mask> to the peasant.
# 261          53                     The athlete is <mask> the lad.
# 270          55              The son is <mask> the father's shoes.
# 280          57    The grandma is <mask> the purse from the thief.
# 290          59                       The mouse is <mask> the cat.
# 305          61                 The patient is <mask> the visitor.
# 310          63     The patient is <mask> flowers to the relative.
# 320          65                  The worker is <mask> at the boss.
# 333          67           The blind person <mask> leading the dog.
# 340          69     The woman is <mask> the bouncer from entering.
# 350          71            The girl is <mask> the dog on the face.
# 361          73                    The woman is <mask> to the man.
# 371          75                 The princess is <mask> the tailor.
# 380          77           The grandmother is <mask> the lifeguard.
# 390          79     The lady is <mask> the door for the chauffeur.
#
#                                           PredictedSeq PredictedToken  \
# 1                     The criminal is blaming the cop.        blaming
# 12                  The child is suing the babysitter.          suing
# 20   The patient is performing a stethoscope on the...     performing
# 30           The grandmother is assisting the fireman.      assisting
# 40                   The patient is suing the dentist.          suing
# 50                      The girl is chasing the ghost.        chasing
# 65                     The baby is killing the mother.        killing
# 70                The businessman is suing the artist.          suing
# 87                    The bride is marrying the groom.       marrying
# 95                     The king is crowned the jester.        crowned
# 100  The Safari guide recommends pouncing on the lion.     recommends
# 110  The model is taking a picture of the photograp...         taking
# 125                The princess is playing the pirate.        playing
# 130                  The bride is marrying the priest.       marrying
# 140               The snorkeler is circling the shark.       circling
# 150         The student is reporting to the professor.      reporting
# 161                  The woman is killing the vampire.        killing
# 171               The customer is thanking the waiter.       thanking
# 180        The beggar is donating money to the lawyer.       donating
# 190                  The lady is waiting for the chef.        waiting
# 200          The grandpa is waiting for the ballerina.        waiting
# 211            The sportsstar is suing the journalist.          suing
# 220                   The criminal is suing the judge.          suing
# 230  The child is accompanying the father on the sled.   accompanying
# 240                The girl is giving Santa a present.         giving
# 252            The queen is sacrificed to the peasant.     sacrificed
# 261                    The athlete is chasing the lad.        chasing
# 270             The son is wearing the father's shoes.        wearing
# 280  The grandma is retrieving the purse from the t...     retrieving
# 290                      The mouse is chasing the cat.        chasing
# 305              The patient is assisting the visitor.      assisting
# 310  The patient is delivering flowers to the relat...     delivering
# 320                 The worker is yelling at the boss.        yelling
# 333           The blind person begins leading the dog.         begins
# 340   The woman is blocking the bouncer from entering.       blocking
# 350          The girl is slapping the dog on the face.       slapping
# 361                The woman is handcuffed to the man.     handcuffed
# 371              The princess is assisting the tailor.      assisting
# 380        The grandmother is assisting the lifeguard.      assisting
# 390    The lady is opening the door for the chauffeur.        opening
#
#     PredictedTokenId       Score IsVerb
# 1              15249   0.0560274      1
# 12             15449    0.100156      1
# 20              4655     0.26774      1
# 30             13390    0.451299      1
# 40             15449     0.31292      1
# 50             11277   0.0516357      1
# 65              2429   0.0187727      1
# 70             15449    0.409334      1
# 87             27372   0.0249293      1
# 95             19061   0.0217693      1
# 100            10827    0.192699      1
# 110              602   0.0821297      1
# 125              816   0.0317078      1
# 130            27372   0.0899048      1
# 140            33633   0.0942286      1
# 150             2207    0.121758      1
# 161             2429   0.0291309      1
# 171            22787    0.044249      1
# 180            16831    0.200398      1
# 190             2445    0.704105      1
# 200             2445    0.328269      1
# 211            15449      0.1024      1
# 220            15449    0.655172      1
# 230            14539    0.235188      1
# 240             1311     0.59401      1
# 252            26936    0.035746      1
# 261            11277   0.0337814      1
# 270             2498    0.388772      1
# 280            43175    0.210686      1
# 290            11277    0.135535      1
# 305            13390   0.0285048      1
# 310             5830    0.156717      1
# 320            16600     0.21668      1
# 333             3772  0.00506404      1
# 340             8890    0.444458      1
# 350            33640     0.39856      1
# 361            27706    0.119441      1
# 371            13390   0.0463652      1
# 380            13390    0.329216      1
# 390             1273    0.250853      1
